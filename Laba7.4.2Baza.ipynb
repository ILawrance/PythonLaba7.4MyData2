# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import pandas as pd

column_names = ['Ядовитый(p - 1) или съедобный(e - 0)', 'cap-shape','cap-surface','cap-color','bruises?', 'odor', 'gill-attachment', 'gill-spacing',
                'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 
                'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',  'ring-type', 
                'spore-print-color', 'population', 'habitat']
raw_dataset = pd.read_csv('mushroom/agaricus-lepiota.data', names=column_names, na_values = "?", comment='\t', skipinitialspace=True)
dataset = raw_dataset.copy()
dataset
# Out:
# 2023-06-20 16:36:49.077799: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-20 16:36:50.687142: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-20 16:36:50.689279: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-20 16:36:55.680971: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#      Ядовитый(p - 1) или съедобный(e - 0) cap-shape cap-surface cap-color
# 0                                       p         x           s         n  \
# 1                                       e         x           s         y
# 2                                       e         b           s         w
# 3                                       p         x           y         w
# 4                                       e         x           s         g
# ...                                   ...       ...         ...       ...
# 8119                                    e         k           s         n
# 8120                                    e         x           s         n
# 8121                                    e         f           s         n
# 8122                                    p         k           y         n
# 8123                                    e         x           s         n
#
#      bruises? odor gill-attachment gill-spacing gill-size gill-color  ...
# 0           t    p               f            c         n          k  ...  \
# 1           t    a               f            c         b          k  ...
# 2           t    l               f            c         b          n  ...
# 3           t    p               f            c         n          n  ...
# 4           f    n               f            w         b          k  ...
# ...       ...  ...             ...          ...       ...        ...  ...
# 8119        f    n               a            c         b          y  ...
# 8120        f    n               a            c         b          y  ...
# 8121        f    n               a            c         b          n  ...
# 8122        f    y               f            c         n          b  ...
# 8123        f    n               a            c         b          y  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring
# 0                           s                      w                      w  \
# 1                           s                      w                      w
# 2                           s                      w                      w
# 3                           s                      w                      w
# 4                           s                      w                      w
# ...                       ...                    ...                    ...
# 8119                        s                      o                      o
# 8120                        s                      o                      o
# 8121                        s                      o                      o
# 8122                        k                      w                      w
# 8123                        s                      o                      o
#
#      veil-type veil-color ring-number ring-type spore-print-color population
# 0            p          w           o         p                 k          s  \
# 1            p          w           o         p                 n          n
# 2            p          w           o         p                 n          n
# 3            p          w           o         p                 k          s
# 4            p          w           o         e                 n          a
# ...        ...        ...         ...       ...               ...        ...
# 8119         p          o           o         p                 b          c
# 8120         p          n           o         p                 b          v
# 8121         p          o           o         p                 b          c
# 8122         p          w           o         e                 w          v
# 8123         p          o           o         p                 o          c
#
#      habitat
# 0          u
# 1          g
# 2          m
# 3          u
# 4          g
# ...      ...
# 8119       l
# 8120       l
# 8121       l
# 8122       l
# 8123       l
#
# [8124 rows x 23 columns]

# %%
dataset.isna().sum()
# Out:
# Ядовитый(p - 1) или съедобный(e - 0)       0
# cap-shape                                  0
# cap-surface                                0
# cap-color                                  0
# bruises?                                   0
# odor                                       0
# gill-attachment                            0
# gill-spacing                               0
# gill-size                                  0
# gill-color                                 0
# stalk-shape                                0
# stalk-root                              2480
# stalk-surface-above-ring                   0
# stalk-surface-below-ring                   0
# stalk-color-above-ring                     0
# stalk-color-below-ring                     0
# veil-type                                  0
# veil-color                                 0
# ring-number                                0
# ring-type                                  0
# spore-print-color                          0
# population                                 0
# habitat                                    0
# dtype: int64

# %%
dataset = dataset.dropna()

data_encoded = pd.get_dummies(dataset, columns=['cap-shape','cap-surface','cap-color','bruises?', 'odor', 'gill-attachment', 'gill-spacing',
                'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 
                'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',  'ring-type', 
                'spore-print-color', 'population', 'habitat'])

data_encoded['Ядовитый(p - 1) или съедобный(e - 0)'] = data_encoded['Ядовитый(p - 1) или съедобный(e - 0)'].replace({'p':1, 'e':0})

# %%
data_encoded.isna().sum()
# Out:
# Ядовитый(p - 1) или съедобный(e - 0)    0
# cap-shape_b                             0
# cap-shape_c                             0
# cap-shape_f                             0
# cap-shape_k                             0
#                                        ..
# habitat_g                               0
# habitat_l                               0
# habitat_m                               0
# habitat_p                               0
# habitat_u                               0
# Length: 99, dtype: int64

# %%
train_dataset = data_encoded.sample(frac=0.8,random_state=0)
test_dataset = data_encoded.drop(train_dataset.index)
test_dataset
# Out:
#       Ядовитый(p - 1) или съедобный(e - 0)  cap-shape_b  cap-shape_c
# 0                                        1        False        False  \
# 7                                        0         True        False
# 21                                       1        False        False
# 24                                       0         True        False
# 25                                       1        False        False
# ...                                    ...          ...          ...
# 7805                                     1        False        False
# 7910                                     1        False        False
# 7919                                     0        False        False
# 7952                                     0        False        False
# 8038                                     0        False        False
#
#       cap-shape_f  cap-shape_k  cap-shape_s  cap-shape_x  cap-surface_f
# 0           False        False        False         True          False  \
# 7           False        False        False        False          False
# 21          False        False        False         True          False
# 24          False        False        False        False          False
# 25           True        False        False        False          False
# ...           ...          ...          ...          ...            ...
# 7805        False        False        False         True          False
# 7910         True        False        False        False          False
# 7919         True        False        False        False          False
# 7952         True        False        False        False          False
# 8038        False        False        False         True          False
#
#       cap-surface_g  cap-surface_s  ...  population_n  population_s
# 0             False           True  ...         False          True  \
# 7             False          False  ...         False          True
# 21            False          False  ...         False         False
# 24            False           True  ...         False          True
# 25            False           True  ...         False         False
# ...             ...            ...  ...           ...           ...
# 7805          False          False  ...         False         False
# 7910          False          False  ...         False         False
# 7919          False          False  ...         False         False
# 7952          False           True  ...         False         False
# 8038          False          False  ...         False         False
#
#       population_v  population_y  habitat_d  habitat_g  habitat_l  habitat_m
# 0            False         False      False      False      False      False  \
# 7            False         False      False      False      False       True
# 21            True         False      False       True      False      False
# 24           False         False      False      False      False       True
# 25            True         False      False       True      False      False
# ...            ...           ...        ...        ...        ...        ...
# 7805         False         False       True      False      False      False
# 7910         False         False       True      False      False      False
# 7919          True         False      False      False      False      False
# 7952          True         False      False      False      False      False
# 8038         False          True      False      False      False      False
#
#       habitat_p  habitat_u
# 0         False       True
# 7         False      False
# 21        False      False
# 24        False      False
# 25        False      False
# ...         ...        ...
# 7805      False      False
# 7910      False      False
# 7919       True      False
# 7952       True      False
# 8038       True      False
#
# [1129 rows x 99 columns]

# %%
train_labels = train_dataset.pop('Ядовитый(p - 1) или съедобный(e - 0)')
test_labels = test_dataset.pop('Ядовитый(p - 1) или съедобный(e - 0)')
print(test_labels)
# Out:
# 0       1
# 7       0
# 21      1
# 24      0
# 25      1
#        ..
# 7805    1
# 7910    1
# 7919    0
# 7952    0
# 8038    0
# Name: Ядовитый(p - 1) или съедобный(e - 0), Length: 1129, dtype: int64

# %%
from tensorflow import keras
from keras import models
from keras import layers
import tensorflow as tf

def build_model():
  model = keras.Sequential([
  layers.Dense(64, activation=tf.nn.relu, input_shape=[len(train_dataset.keys())]),
  layers.Dense(64, activation=tf.nn.relu),
  layers.Dense(1, activation=tf.nn.sigmoid)
  ])
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
  return model
model = build_model()

model.summary()

#model = keras.Sequential()
#model.add(keras.layers.Dense(64, activation=tf.nn.relu, input_shape=[len(train_dataset.keys())])),
#model.add(keras.layers.Dense(16, activation=tf.nn.relu))
#model.add(keras.layers.Dense(1, activation=tf.nn.sigmoid))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                6336
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 10,561
# Trainable params: 10,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_val = train_dataset[:3000]
partial_x_train = train_dataset[3000:]

y_val = train_labels[:3000]
partial_y_train = train_labels[3000:]

# %%
history = model.fit(partial_x_train,
partial_y_train,
epochs=20,
batch_size=128,
validation_data=(x_val, y_val),
verbose=1)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 2s 35ms/step - loss: 0.6284 - accuracy: 0.6944 - val_loss: 0.5025 - val_accuracy: 0.8590
# Epoch 2/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.4181 - accuracy: 0.8561 - val_loss: 0.3320 - val_accuracy: 0.8610
# Epoch 3/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2619 - accuracy: 0.8812 - val_loss: 0.1970 - val_accuracy: 0.9287
# Epoch 4/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1407 - accuracy: 0.9769 - val_loss: 0.0993 - val_accuracy: 0.9910
# Epoch 5/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0656 - accuracy: 0.9960 - val_loss: 0.0481 - val_accuracy: 0.9960
# Epoch 6/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0311 - accuracy: 0.9980 - val_loss: 0.0262 - val_accuracy: 0.9983
# Epoch 7/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0167 - accuracy: 0.9993 - val_loss: 0.0163 - val_accuracy: 0.9993
# Epoch 8/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9993
# Epoch 9/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9993
# Epoch 10/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9993
# Epoch 11/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9993
# Epoch 12/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 0.9993
# Epoch 13/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9997
# Epoch 14/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9997
# Epoch 15/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 16/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 17/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 18/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 19/20
# 12/12 [==============================] - 0s 9ms/step - loss: 9.9485e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 20/20
# 12/12 [==============================] - 0s 9ms/step - loss: 8.8234e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" означает "blue dot", синяя точка
plt.plot(epochs, loss, 'bo', label='Потери обучения')
# "b" означает "solid blue line", непрерывная синяя линия
plt.plot(epochs, val_loss, 'b', label='Потери проверки')
plt.title('Потери во время обучения и проверки')
plt.xlabel('Эпохи')
plt.ylabel('Потери')
plt.legend()

plt.show()

# %%
plt.clf() 
# Очистим график

plt.plot(epochs, acc, 'bo', label='Точность обучения')
plt.plot(epochs, val_acc, 'b', label='Точность проверки')
plt.title('Точность во время обучения и проверки')
plt.xlabel('Эпохи')
plt.ylabel('Точность')
plt.legend()
plt.show()

# %%
loss, results = model.evaluate(test_dataset, test_labels)
print("Точность: ", results)
print("Потери: ", loss)
# Out:
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Точность:  1.0
# Потери:  0.0016465522348880768

# %%
model.save('model_baza.h5')

model_baza = keras.models.load_model('model_baza.h5')

test_loss, test_acc = model_baza.evaluate(test_dataset, test_labels)


train_loss, train_acc = model_baza.evaluate(train_dataset, train_labels)

print("Восстановленная модель, точность: {:5.2f}%".format(100*test_acc))
# Out:
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Восстановленная модель, точность: 100.00%

# %%
import pandas as pd

Tablica = pd.DataFrame([['Базовая модель',round(100*train_acc, 2), round(100*train_loss, 2), round(100*test_acc, 2), round(100*test_loss, 2)],
                   ['Модель с 32 нейронами', round(100*train_acc1, 2), round(100*train_loss1, 2), round(100*test_acc1, 2), round(100*test_loss1, 2)],
                   ['Модель с 3 скрытыми слоями',round(100*train_acc2, 2), round(100*train_loss2, 2), round(100*test_acc2, 2), round(100*test_loss2, 2)],
                   ['Модель с функцией потерь mean_squared_error',round(100*train_acc3, 2), round(100*train_loss3, 2), round(100*test_acc3, 2), round(100*test_loss3, 2)],
                   ['Модель с функцией активации tanh',round(100*train_acc4, 2), round(100*train_loss4, 2), round(100*test_acc4, 2), round(100*test_loss4, 2)]],
                   columns=['Параметры модели','Точность учебного набора', 'Потери учебного набора', 'Точность контрольного набора ', 'Потери контрольного набора'])

Tablica
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 import pandas as pd
#       3 Tablica = pd.DataFrame([['Базовая модель',round(100*train_acc, 2), round(100*train_loss, 2), round(100*test_acc, 2), round(100*test_loss, 2)],
# ----> 4                    ['Модель с 3 скрытыми слоями', round(100*train_acc1, 2), round(100*train_loss1, 2), round(100*test_acc1, 2), round(100*test_loss1, 2)],
#       5                    ['Модель с 64 нейронами',round(100*train_acc2, 2), round(100*train_loss2, 2), round(100*test_acc2, 2), round(100*test_loss2, 2)],
#       6                    ['Модель с функцией потерь mean_squared_error',round(100*train_acc3, 2), round(100*train_loss3, 2), round(100*test_acc3, 2), round(100*test_loss3, 2)],
#       7                    ['Модель с функцией активации tanh',round(100*train_acc4, 2), round(100*train_loss4, 2), round(100*test_acc4, 2), round(100*test_loss4, 2)]],
#       8                    columns=['Параметры модели','Точность учебного набора', 'Потери учебного набора', 'Точность контрольного набора ', 'Потери контрольного набора'])
#      10 Tablica
#
# NameError: name 'train_acc1' is not defined
